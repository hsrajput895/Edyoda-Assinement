# %% [markdown]
# <a href="https://colab.research.google.com/github/hsrajput895/Edyoda-Assinement/blob/main/knn%20assinement.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-c0681d2d-57d7-4463-8ed0-e7d5562bf86d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c0681d2d-57d7-4463-8ed0-e7d5562bf86d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("house_rental_data.csv.txt")

# %%
df
# Out:
#      Unnamed: 0      Sqft  Floor  TotalFloor  Bedroom  Living.Room  Bathroom  \
# 0             1  1177.698      2           7        2            2         2
# 1             2  2134.800      5           7        4            2         2
# 2             3  1138.560      5           7        2            2         1
# 3             4  1458.780      2           7        3            2         2
# 4             5   967.776     11          14        3            2         2
# ..          ...       ...    ...         ...      ...          ...       ...
# 640         644  1359.156      7          15        3            2         2
# 641         645   377.148      4          10        1            1         1
# 642         646   740.064     13          14        1            1         1
# 643         647  1707.840      3          14        3            2         2
# 644         648  1376.946      6           7        3            2         1
#
#      Price
# 0    62000
# 1    78000
# ...

# %%
df.head()
# Out:
#    Unnamed: 0      Sqft  Floor  TotalFloor  Bedroom  Living.Room  Bathroom  \
# 0           1  1177.698      2           7        2            2         2
# 1           2  2134.800      5           7        4            2         2
# 2           3  1138.560      5           7        2            2         1
# 3           4  1458.780      2           7        3            2         2
# 4           5   967.776     11          14        3            2         2
#
#    Price
# 0  62000
# 1  78000
# 2  58000
# 3  45000
# 4  45000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 645 entries, 0 to 644
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   645 non-null    int64
#  1   Sqft         645 non-null    float64
#  2   Floor        645 non-null    int64
#  3   TotalFloor   645 non-null    int64
#  4   Bedroom      645 non-null    int64
#  5   Living.Room  645 non-null    int64
#  6   Bathroom     645 non-null    int64
#  7   Price        645 non-null    int64
# dtypes: float64(1), int64(7)
# memory usage: 40.4 KB

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Sqft', 'Floor', 'TotalFloor', 'Bedroom', 'Living.Room',
#        'Bathroom', 'Price'],
#       dtype='object')

# %%
X = df.drop(['Unnamed: 0','Price'], axis = 1)
y = df['Price']

# %%
y
# Out:
# 0      62000
# 1      78000
# 2      58000
# 3      45000
# 4      45000
#        ...
# 640    45000
# 641    24800
# 642    45000
# 643    65000
# 644    36000
# Name: Price, Length: 645, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .2, random_state = 0,stratify = y.iloc[1:,1])
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# <ipython-input-37-7d17f1767ea0> in <module>
#       1 from sklearn.model_selection import train_test_split
# ----> 2 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .2, random_state = 0,stratify = y.iloc[1:,1])
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#     923                 with suppress(KeyError, IndexError):
#     924                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 925             return self._getitem_tuple(key)
#     926         else:
#     927             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1504     def _getitem_tuple(self, tup: tuple):
#    1505
# -> 1506         self._has_valid_tuple(tup)
# ...

# %%
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((516, 6), (516,), (129, 6), (129,))

# %%
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier()

# %%
model.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
model.score(X_test, y_test)
# Out:
# 0.09302325581395349
